# %%
import re
import pandas as pd

# %%
def extract_data(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        data = file.readlines()

    pattern = r'\[(.*?)\] ([^:]+): (.*)'
    parsed_data = []

    for line in data:
        match = re.match(pattern, line.strip())
        if match:
            parsed_data.append(match.groups())

    df = pd.DataFrame(parsed_data, columns=['Timestamp', 'Sender', 'Message'])
    df.drop(columns=['Timestamp'], inplace=True)
    
    return df

def main(file_path):
    df = extract_data(file_path)
    display(df)
        
if __name__ == "__main__":
    file_path = 'chat.txt'
    main(file_path)
# Out:
#                       Sender  \
# 0      Bible Reading Cycle 2
# 1         Lenny Pandjidharma
# 2      Bible Reading Cycle 2
# 3          Vik. Dessy Waiman
# 4         Lenny Pandjidharma
# ...                      ...
# 19027            ~ Andrie HG
# 19028            ~ Andrie HG
# 19029      Vik. Dessy Waiman
# 19030                  ~ Tom
# 19031  Bible Reading Cycle 2
#
#                                                  Message
# 0      ‎Pesan dan panggilan terenkripsi secara end-to...
# 1      ‎Lenny Pandjidharma membuat grup “Bible Readin...
# 2                   ‎Lenny Pandjidharma menambahkan Anda
# 3      ‎Lenny Pandjidharma menambahkan Vik. Dessy Waiman
# 4            ‎Lenny Pandjidharma mengubah deskripsi grup
# ...                                                  ...
# 19027                           ‎~ Andrie HG ditambahkan
# 19028                       Terima kasih bu dessy 🙏🏽🙏🏽🙏🏽
# 19029                               Sama-sama pak Andrie
# 19030              ‎Vik. Dessy Waiman mengeluarkan ~ Tom
# 19031               ‎Vik. Dessy Waiman mengeluarkan Anda
#
# [19032 rows x 2 columns]

# %%
def classify_message(message):
    keywords = ['done', 'selesai', 'sudah', '✅', '✓']
    for keyword in keywords:
        if keyword in message.lower():
            return 'report'
    return 'not report'

# %%
def main(file_path, output_file):
    df = extract_data(file_path)
    df['Category'] = df['Message'].apply(classify_message)
    df.to_csv(output_file, index=False)
        
if __name__ == "__main__":
    input_file_path = 'chat.txt'
    output_file_path = 'classifiedchat.csv'
    main(input_file_path, output_file_path)
