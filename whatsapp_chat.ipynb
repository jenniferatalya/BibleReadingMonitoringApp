# %%
import os
import re
import pandas as pd
from collections import Counter
from jaro import jaro_winkler_metric

# %%
def extract_data(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        data = file.readlines()

    pattern = r'\[(.*?)\] ([^:]+): (.*)'
    parsed_data = []

    for line in data:
        match = re.match(pattern, line.strip())
        if match:
            parsed_data.append(match.groups())

    df = pd.DataFrame(parsed_data, columns=['Timestamp', 'Sender', 'Message'])
    df['Timestamp'] = pd.to_datetime(df['Timestamp'], format='%d/%m/%y %H.%M.%S')
    df['Date'] = df['Timestamp'].dt.date
    df['Time'] = df['Timestamp'].dt.time
    df.drop(columns=['Timestamp'], inplace=True)
    
    return df

def split_by_day(df):
    grouped = df.groupby('Date')
    daily_dfs = [group for _, group in grouped]
    return daily_dfs

def main(file_path):
    df = extract_data(file_path)
    daily_dfs = split_by_day(df)
    
    if not os.path.exists("chat"):
        os.makedirs("chat")

    for i, daily_df in enumerate(daily_dfs, start=1):
        chat_date = str(daily_df['Date'].iloc[0])
        file_name = f"chat/{chat_date}.csv"
        daily_df.to_csv(file_name, index=False)
        
if __name__ == "__main__":
    file_path = 'chat.txt'
    main(file_path)

# %%
df = pd.read_csv("chat/2020-08-03.csv")
df['Message'] = df['Message'].str.lower()
display(df)
# Out:
#                          Sender  \
# 0               Melanie Chandra
# 1          ~ Lindawati Haryanto
# 2                Sherly Cahyadi
# 3                  ~ Seto Ninik
# 4                   ~ 🪸Martha 🍁
# 5                ~ Dewi Pratiwi
# 6               ~ Endang Surati
# 7                 Dicky Andrian
# 8                           ~ 🎍
# 9     ~ dr. Andreas C.N., Sp.B.
# 10                   ~ Oma Lisa
# 11           Lenny Pandjidharma
# 12                  Ibu Kartika
# 13   ~ Kristin WIjaya Nusantara
# 14                Yozef Tjandra
# 15                  Ibu Kartika
# 16                     ~ Mfitri
# 17                      ~ Bento
# 18                 ~ Ivan teguh
# 19                        ~ Tom
# 20                     ~ piccer
# 21                      ~ Agnes
# 22               Darius Handoko
# 23                      ~ Agnes
# 24               Darius Handoko
# 25              Matthew Henry 2
# 26                   ~ Oma Lisa
# 27  ~ Helen Fransiska Margarita
# 28              ~ Tjunfebelyana
# 29              ~ Tjunfebelyana
# 30                ~ BL katering
# 31                     ~ Yoppie
# 32                    ~ scarlet
# 33      ~ Nathanael Jeffry Teja
# 34                      ~ Wiwik
# 35                      ~ Moses
# 36                     ~ Gracia
# 37                       ~ Noah
# 38                 Ruri Handoko
# 39           ~ Wesley and Mom😇🥰
# 40              ~ Villas Bakery
# 41                  ~ no vi3ika
# 42                         ~ LF
# 43              ~ Tjunfebelyana
# 44              ~ Tjunfebelyana
# 45                ~ Tejo Jayadi
# 46                  Sim Ay Tjan
#
#                                            Message        Date      Time
# 0                                     kej 1-2 done  2020-08-03  03:48:55
# 1                                     kej 1-2 done  2020-08-03  04:03:51
# 2                                     kej 1-2 done  2020-08-03  04:08:44
